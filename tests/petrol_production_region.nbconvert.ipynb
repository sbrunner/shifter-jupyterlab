# %%
# https://www.bp.com/en/global/corporate/energy-economics/statistical-review-of-world-energy.html

from shifter_pandas.bp import BPDatasource

shifter_ds = BPDatasource("data/bp-stats-review-2021-all-data.xlsx")

# %%
df = shifter_ds.datasource(
    types_filter=["Oil Production - Barrels"],
)
df
# Out:
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# ...
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
# /home/runner/.local/lib/python3.8/site-packages/shifter_pandas/bp.py:376: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_frame = data_frame.append(element, ignore_index=True)
#                Value                      Type        Unit  \
# 0      146268.561798  Oil Production - Barrels  m³ per day
# 1       57553.499316  Oil Production - Barrels  m³ per day
# 2     1433137.460651  Oil Production - Barrels  m³ per day
# 3     1636959.521765  Oil Production - Barrels  m³ per day
# 4       43828.734237  Oil Production - Barrels  m³ per day
# ...              ...                       ...         ...
# 3507    4486061.1366  Oil Production - Barrels  m³ per day
# 3508  9567025.200766  Oil Production - Barrels  m³ per day
# 3509  4870789.473057  Oil Production - Barrels  m³ per day
# 3510  9182296.864308  Oil Production - Barrels  m³ per day
# 3511    62694.963159  Oil Production - Barrels  m³ per day
#
#                                    TypeUnit  Year  \
# 0     Oil Production - Barrels [m³ per day]  1965
# 1     Oil Production - Barrels [m³ per day]  1965
# 2     Oil Production - Barrels [m³ per day]  1965
# 3     Oil Production - Barrels [m³ per day]  1965
# 4     Oil Production - Barrels [m³ per day]  1965
# ...                                     ...   ...
# 3507  Oil Production - Barrels [m³ per day]  2020
# 3508  Oil Production - Barrels [m³ per day]  2020
# 3509  Oil Production - Barrels [m³ per day]  2020
# 3510  Oil Production - Barrels [m³ per day]  2020
# 3511  Oil Production - Barrels [m³ per day]  2020
#
#                                  Region
# 0                                Canada
# 1                                Mexico
# 2                                    US
# 3                   Total North America
# 4                             Argentina
# ...                                 ...
# 3507                     of which: OECD
# 3508                           Non-OECD
# 3509                               OPEC
# 3510                          Non-OPEC
# 3511                   European Union #
#
# [3512 rows x 6 columns]

# %%
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash

# Build App
app = JupyterDash("Oil Production - Barrels")
app.layout = html.Div(
    [
        html.Label(
            [
                "Region",
                dcc.Dropdown(
                    id="dropdown",
                    clearable=False,
                    value="Total World",
                    options=[{"label": c, "value": c} for c in set(df["Region"])],
                ),
            ]
        ),
        dcc.Graph(id="graph"),
    ]
)

# Define callback to update graph
@app.callback(Output("graph", "figure"), [Input("dropdown", "value")])
def update_figure(region):
    fig = px.line(df.query(f'Region == "{region}"'), x="Year", y="Value")
    fig.update_layout(
        yaxis_type="log",
        xaxis={"rangeslider": {"visible": True}},
        title="Oil Production - Barrels",
    )
    return fig


# Run app and display result inline in the notebook
app.run_server(mode="inline", port=8051)
# Out:
# /tmp/ipykernel_2028/2204377789.py:1: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /tmp/ipykernel_2028/2204377789.py:2: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
