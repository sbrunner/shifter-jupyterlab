# %%
# Import packages
import pandas as pd
# https://github.com/owid/covid-19-data/tree/master/public/data
df = pd.read_csv("owid-covid-data.csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 163085      ZWE    Africa     Zimbabwe  2022-02-15     231603.0        0.0
# 163086      ZWE    Africa     Zimbabwe  2022-02-16     232213.0      610.0
# 163087      ZWE    Africa     Zimbabwe  2022-02-17     232598.0      385.0
# 163088      ZWE    Africa     Zimbabwe  2022-02-18     233030.0      432.0
# 163089      ZWE    Africa     Zimbabwe  2022-02-19     233224.0      194.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 163085             142.857        5374.0         0.0                1.143
# 163086             210.429        5379.0         5.0                1.714
# 163087             222.571        5381.0         2.0                1.143
# 163088             259.429        5385.0         4.0                1.571
# 163089             275.000        5386.0         1.0                1.714
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 163085  ...             1.6          30.7                  36.791
# 163086  ...             1.6          30.7                  36.791
# 163087  ...             1.6          30.7                  36.791
# 163088  ...             1.6          30.7                  36.791
# 163089  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 163085                         1.7            61.49                    0.571
# 163086                         1.7            61.49                    0.571
# 163087                         1.7            61.49                    0.571
# 163088                         1.7            61.49                    0.571
# 163089                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 163085                                   NaN                          NaN
# 163086                                   NaN                          NaN
# 163087                                   NaN                          NaN
# 163088                                   NaN                          NaN
# 163089                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 163085               NaN                                      NaN
# 163086               NaN                                      NaN
# 163087               NaN                                      NaN
# 163088               NaN                                      NaN
# 163089               NaN                                      NaN
#
# [163090 rows x 67 columns]

# %%
df2 = df.query("location in ['Oceania', 'Asia', 'Europe', 'South America', 'North America', 'Africa']")
df2
# Out:
#         iso_code continent       location        date  total_cases  new_cases  \
# 727     OWID_AFR       NaN         Africa  2020-02-13          NaN        0.0
# 728     OWID_AFR       NaN         Africa  2020-02-14          1.0        1.0
# 729     OWID_AFR       NaN         Africa  2020-02-15          1.0        0.0
# 730     OWID_AFR       NaN         Africa  2020-02-16          1.0        0.0
# 731     OWID_AFR       NaN         Africa  2020-02-17          1.0        0.0
# ...          ...       ...            ...         ...          ...        ...
# 136754  OWID_SAM       NaN  South America  2022-02-15   52355561.0   191443.0
# 136755  OWID_SAM       NaN  South America  2022-02-16   52562482.0   206921.0
# 136756  OWID_SAM       NaN  South America  2022-02-17   52776087.0   213605.0
# 136757  OWID_SAM       NaN  South America  2022-02-18   52980974.0   204887.0
# 136758  OWID_SAM       NaN  South America  2022-02-19   53150414.0   169440.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 727                    NaN           NaN         0.0                  NaN
# 728                    NaN           NaN         0.0                  NaN
# 729                    NaN           NaN         0.0                  NaN
# 730                    NaN           NaN         0.0                  NaN
# 731                    NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 136754          211091.286     1240668.0      1595.0             1638.429
# 136755          200663.143     1242153.0      1485.0             1549.857
# 136756          193958.714     1244196.0      2043.0             1596.000
# 136757          185178.429     1246020.0      1824.0             1559.857
# 136758          179234.429     1247519.0      1499.0             1561.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 727     ...             NaN           NaN                     NaN
# 728     ...             NaN           NaN                     NaN
# 729     ...             NaN           NaN                     NaN
# 730     ...             NaN           NaN                     NaN
# 731     ...             NaN           NaN                     NaN
# ...     ...             ...           ...                     ...
# 136754  ...             NaN           NaN                     NaN
# 136755  ...             NaN           NaN                     NaN
# 136756  ...             NaN           NaN                     NaN
# 136757  ...             NaN           NaN                     NaN
# 136758  ...             NaN           NaN                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 727                            NaN              NaN                      NaN
# 728                            NaN              NaN                      NaN
# 729                            NaN              NaN                      NaN
# 730                            NaN              NaN                      NaN
# 731                            NaN              NaN                      NaN
# ...                            ...              ...                      ...
# 136754                         NaN              NaN                      NaN
# 136755                         NaN              NaN                      NaN
# 136756                         NaN              NaN                      NaN
# 136757                         NaN              NaN                      NaN
# 136758                         NaN              NaN                      NaN
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 727                                      NaN                          NaN
# 728                                      NaN                          NaN
# 729                                      NaN                          NaN
# 730                                      NaN                          NaN
# 731                                      NaN                          NaN
# ...                                      ...                          ...
# 136754                                   NaN                          NaN
# 136755                                   NaN                          NaN
# 136756                                   NaN                          NaN
# 136757                                   NaN                          NaN
# 136758                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 727                  NaN                                      NaN
# 728                  NaN                                      NaN
# 729                  NaN                                      NaN
# 730                  NaN                                      NaN
# 731                  NaN                                      NaN
# ...                  ...                                      ...
# 136754               NaN                                      NaN
# 136755               NaN                                      NaN
# 136756               NaN                                      NaN
# 136757               NaN                                      NaN
# 136758               NaN                                      NaN
#
# [4503 rows x 67 columns]

# %%
df2.insert(4, 'td_tc', df2["total_deaths"] / df2["total_cases"])
df2
# Out:
#         iso_code continent       location        date     td_tc  total_cases  \
# 727     OWID_AFR       NaN         Africa  2020-02-13       NaN          NaN
# 728     OWID_AFR       NaN         Africa  2020-02-14       NaN          1.0
# 729     OWID_AFR       NaN         Africa  2020-02-15       NaN          1.0
# 730     OWID_AFR       NaN         Africa  2020-02-16       NaN          1.0
# 731     OWID_AFR       NaN         Africa  2020-02-17       NaN          1.0
# ...          ...       ...            ...         ...       ...          ...
# 136754  OWID_SAM       NaN  South America  2022-02-15  0.023697   52355561.0
# 136755  OWID_SAM       NaN  South America  2022-02-16  0.023632   52562482.0
# 136756  OWID_SAM       NaN  South America  2022-02-17  0.023575   52776087.0
# 136757  OWID_SAM       NaN  South America  2022-02-18  0.023518   52980974.0
# 136758  OWID_SAM       NaN  South America  2022-02-19  0.023471   53150414.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 727           0.0                 NaN           NaN         0.0  ...
# 728           1.0                 NaN           NaN         0.0  ...
# 729           0.0                 NaN           NaN         0.0  ...
# 730           0.0                 NaN           NaN         0.0  ...
# 731           0.0                 NaN           NaN         0.0  ...
# ...           ...                 ...           ...         ...  ...
# 136754   191443.0          211091.286     1240668.0      1595.0  ...
# 136755   206921.0          200663.143     1242153.0      1485.0  ...
# 136756   213605.0          193958.714     1244196.0      2043.0  ...
# 136757   204887.0          185178.429     1246020.0      1824.0  ...
# 136758   169440.0          179234.429     1247519.0      1499.0  ...
#
#         female_smokers  male_smokers  handwashing_facilities  \
# 727                NaN           NaN                     NaN
# 728                NaN           NaN                     NaN
# 729                NaN           NaN                     NaN
# 730                NaN           NaN                     NaN
# 731                NaN           NaN                     NaN
# ...                ...           ...                     ...
# 136754             NaN           NaN                     NaN
# 136755             NaN           NaN                     NaN
# 136756             NaN           NaN                     NaN
# 136757             NaN           NaN                     NaN
# 136758             NaN           NaN                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 727                            NaN              NaN                      NaN
# 728                            NaN              NaN                      NaN
# 729                            NaN              NaN                      NaN
# 730                            NaN              NaN                      NaN
# 731                            NaN              NaN                      NaN
# ...                            ...              ...                      ...
# 136754                         NaN              NaN                      NaN
# 136755                         NaN              NaN                      NaN
# 136756                         NaN              NaN                      NaN
# 136757                         NaN              NaN                      NaN
# 136758                         NaN              NaN                      NaN
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 727                                      NaN                          NaN
# 728                                      NaN                          NaN
# 729                                      NaN                          NaN
# 730                                      NaN                          NaN
# 731                                      NaN                          NaN
# ...                                      ...                          ...
# 136754                                   NaN                          NaN
# 136755                                   NaN                          NaN
# 136756                                   NaN                          NaN
# 136757                                   NaN                          NaN
# 136758                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 727                  NaN                                      NaN
# 728                  NaN                                      NaN
# 729                  NaN                                      NaN
# 730                  NaN                                      NaN
# 731                  NaN                                      NaN
# ...                  ...                                      ...
# 136754               NaN                                      NaN
# 136755               NaN                                      NaN
# 136756               NaN                                      NaN
# 136757               NaN                                      NaN
# 136758               NaN                                      NaN
#
# [4503 rows x 68 columns]

# %%
import plotly.express as px

print(set(df['continent']))
fig = px.line(df2, x="date", 
#              y="new_deaths", 
#              y="new_cases", 
#              y="total_deaths", 
#              y="total_cases", 
              y="td_tc", 
              color='location')
fig.update_layout(yaxis_type="log",
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
    )
)
fig.show()
# Out:
# {nan, 'Oceania', 'Asia', 'Europe', 'South America', 'North America', 'Africa'}
